# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_digits

# %%
digit= load_digits()
dir(digit)
# Out:
# ['DESCR', 'data', 'feature_names', 'frame', 'images', 'target', 'target_names']

# %%
model_params={
    'RandomForest':{
        'model': RandomForestClassifier(),
        'params':{
            'n_estimators': [2,4,6,8]
        }
    },

    'LogisticRegression':{
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params':{
            'C': [2,4,6,8]
        }
    },

    'GaussianNB':{
       'model': GaussianNB(),
        'params':{

        }
    },

    'MultinomialNB':{
        'model': MultinomialNB(),
        'params':{

        }
    },

    'DecisionTreeClassifier':{
         'model': DecisionTreeClassifier(),
        'params':{
            'criterion': ['gini','entropy']
        }
    }


}

# %%
from sklearn.model_selection import GridSearchCV
scores=[]
for mn,mp in model_params.items():
  print(mn)
  print(mp)
  clf= GridSearchCV(mp['model'],mp['params'],cv=5,return_train_score=False)
  clf.fit(digit.data,digit.target)
  scores.append({
      'model':mn,
      'best_params':clf.best_params_,
      'best_score':clf.best_score_
  })
  df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
# RandomForest
# {'model': RandomForestClassifier(), 'params': {'n_estimators': [2, 4, 6, 8]}}
# LogisticRegression
# {'model': LogisticRegression(solver='liblinear'), 'params': {'C': [2, 4, 6, 8]}}
# GaussianNB
# {'model': GaussianNB(), 'params': {}}
# MultinomialNB
# {'model': MultinomialNB(), 'params': {}}
# DecisionTreeClassifier
# {'model': DecisionTreeClassifier(), 'params': {'criterion': ['gini', 'entropy']}}
#                     model  best_score               best_params
# 0            RandomForest    0.887617       {'n_estimators': 8}
# 1      LogisticRegression    0.920446                  {'C': 2}
# 2              GaussianNB    0.806928                        {}
# 3           MultinomialNB    0.870350                        {}
# 4  DecisionTreeClassifier    0.813055  {'criterion': 'entropy'}
