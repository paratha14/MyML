# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

# %%
iris= load_iris()
dir(iris)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
df=pd.DataFrame(iris.data,columns=iris.feature_names)
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
df['flower']=iris.target
df['flower']=df.flower.apply(lambda x : iris.target_names[x])
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#         flower
# 0       setosa
# ...

# %%
#using searchgridcv method
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
clf= GridSearchCV(LogisticRegression(solver='liblinear',multi_class='auto'),
                  {'C':[1,5,10]},
                  cv=3,
                  return_train_score=False
                  )
clf.fit(iris.data,iris.target)
# Out:
# GridSearchCV(cv=3, estimator=LogisticRegression(solver='liblinear'),
#              param_grid={'C': [1, 5, 10]})

# %%
clf.cv_results_
# Out:
# {'mean_fit_time': array([0.00133403, 0.00139316, 0.00156562]),
#  'std_fit_time': array([7.66906096e-05, 4.58926693e-05, 4.14621418e-05]),
#  'mean_score_time': array([0.00100748, 0.00091394, 0.00079735]),
#  'std_score_time': array([2.71506554e-05, 7.11447681e-05, 1.66214213e-05]),
#  'param_C': masked_array(data=[1, 5, 10],
#               mask=[False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'C': 1}, {'C': 5}, {'C': 10}],
#  'split0_test_score': array([0.96, 0.98, 1.  ]),
#  'split1_test_score': array([0.96, 0.96, 0.96]),
#  'split2_test_score': array([0.94, 0.96, 0.96]),
#  'mean_test_score': array([0.95333333, 0.96666667, 0.97333333]),
#  'std_test_score': array([0.00942809, 0.00942809, 0.01885618]),
#  'rank_test_score': array([3, 2, 1], dtype=int32)}

# %%
result=pd.DataFrame(clf.cv_results_)
result
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0       0.001334      0.000077         0.001007        0.000027       1
# 1       0.001393      0.000046         0.000914        0.000071       5
# 2       0.001566      0.000041         0.000797        0.000017      10
#
#       params  split0_test_score  split1_test_score  split2_test_score  \
# 0   {'C': 1}               0.96               0.96               0.94
# 1   {'C': 5}               0.98               0.96               0.96
# 2  {'C': 10}               1.00               0.96               0.96
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.953333        0.009428                3
# 1         0.966667        0.009428                2
# 2         0.973333        0.018856                1

# %%
result[['param_C','mean_test_score']]
# Out:
#   param_C  mean_test_score
# 0       1         0.953333
# 1       5         0.966667
# 2      10         0.973333

# %%
#now using Randomisedsearchgrid
rsg= RandomizedSearchCV(LogisticRegression(solver='liblinear',multi_class='auto'),{'C':[1,7,11]},cv=5,return_train_score=False,n_iter=2)
rsg.fit(iris.data,iris.target)
# Out:
# RandomizedSearchCV(cv=5, estimator=LogisticRegression(solver='liblinear'),
#                    n_iter=2, param_distributions={'C': [1, 7, 11]})

# %%
re= pd.DataFrame(rsg.cv_results_)
re
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0       0.001757      0.000483         0.000877        0.000151       1
# 1       0.001486      0.000157         0.000801        0.000090       7
#
#      params  split0_test_score  split1_test_score  split2_test_score  \
# 0  {'C': 1}                1.0           0.966667           0.933333
# 1  {'C': 7}                1.0           1.000000           0.933333
#
#    split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0                0.9                1.0         0.960000        0.038873
# 1                0.9                1.0         0.966667        0.042164
#
#    rank_test_score
# 0                2
# 1                1

# %%
re[['param_C','mean_test_score']]
# Out:
#   param_C  mean_test_score
# 0       1         0.960000
# 1       7         0.966667

# %%
#now for hyperparametre tunning

model_params={


    'forest':{
        'model':RandomForestClassifier(),
        'params': {
            'n_estimators':[1,7,12]
        }
    },

    'logisticregression':{
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params':{'C':[1,7,12]}
    }
}

# %%
score= []
for mn,mp in model_params.items():
  clf=GridSearchCV(mp['model'],mp['params'],cv=5,return_train_score=False)
  clf.fit(iris.data,iris.target)
  score.append({
      'model':mn,
      'best_params':clf.best_params_,
      'best_score':clf.best_score_
  })

# %%
df=pd.DataFrame(score)

# %%
df
# Out:
#                 model           best_params  best_score
# 0              forest  {'n_estimators': 12}    0.960000
# 1  logisticregression              {'C': 7}    0.966667
